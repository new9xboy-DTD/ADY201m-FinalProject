# %% [markdown]
# # <h1 align="center"> ADY201 final project <h1/>

# %% [markdown]
# ## GROUP:
# ### Group member:
# ### Group member:
# ### Group member:
# ### Group member:
# ### Group member:

# %% [markdown]
# ---
#
# ### 1. TASK
#
# 1.1. Activity name: Build a machine learning model in Python with a dataset of your choice.
#
# 1.2. Objectives:
#
# * Master the basic workflow of building a machine learning model.
# * Apply skills in data preprocessing, visualization, model selection, and model evaluation.
# * Practice using Python and popular machine learning libraries (such as caret, randomForest, e1071, glmnet, xgboost, etc.).
# * Develop skills in presenting results in a reproducible notebook format.
#
# ### 2. DETAILED REQUIREMENTS
#
# 1. Select an appropriate dataset
#
# * Must contain at least 500 rows of data and 5 or more feature columns.
# * Can be selected from: UCI, Kaggle, OpenML, or available datasets in R (iris, mtcars, airquality, Boston, diamonds, etc.).
#
# 2. Modeling objective
#
# * Choose a classification or regression problem suitable for the dataset.
# * Clearly specify target variable and feature variables.
#
# 3. Data preprocessing
#
# * Check and handle missing values.
# * Normalize or transform data if necessary (One-Hot Encoding, Scaling, etc.).
# * Split the dataset into train/test sets (e.g.: 70/30 or 80/20).
#
# 4. Data visualization
#
# * Provide visual representations (histogram, boxplot, scatterplot, correlation heatmap, etc.).
# * Analyze relationships and distribution of variables.
#
# 5. Train machine learning model
#
# * Apply at least one machine learning model (e.g.: linear regression, logistic regression, random forest, decision tree, SVM, kNN, xgboost, etc.).
# * Perform hyperparameter tuning if possible.
#
# 6. Model evaluation
#
# * Use appropriate evaluation metrics:
#
#   * Regression: RMSE, MAE, R²
#   * Classification: Accuracy, Confusion Matrix, Precision/Recall/F1-score, ROC/AUC
# * Provide remarks on model performance.
#
# 7. Documentation in Notebook
#
# * Code must include clear comments and explanation.
# * Present analysis, model selection rationale, and well-founded conclusions.
#
# ### 3. PROJECT REQUIREMENTS
#
# * Completed using Jupyter Notebook (.ipynb or .html format).
# * Must run completely without errors.
# * Include data description, result analysis, and final conclusion.
# * Group presentation with all members participating. Presentation time: Slot 1 of Week 10 according to FAP schedule.
#
# ### 4. GRADING CRITERIA (10-point scale)
#
# | Criteria                             | Description                                           | Points |
# | ------------------------------------ | ----------------------------------------------------- | ------ |
# | 1. Dataset selection & understanding | Clear and appropriate explanation of the dataset      | 1      |
# | 2. Data preprocessing                | Proper handling of missing values and transformations | 1.5    |
# | 3. Data visualization                | Good use of charts and graphical analysis             | 1      |
# | 4. Machine learning model            | Correct and suitable model implementation             | 1.5    |
# | 5. Model evaluation                  | Appropriate methods with clear explanation            | 1      |
# | 6. Presentation & Reporting          | Clear writing, logic, reproducibility                 | 3      |
#
# ---

# %%
x.head()
